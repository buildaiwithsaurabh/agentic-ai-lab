# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = "Generative artificial intelligence (GenAI) is a subfield of artificial intelligence (AI) that uses generative models to generate text, images, videos, audio, software code or other forms of data.\n\nThese models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\n\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture."

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=10)

# %%
chunks = splitter.split_text(text)

# %%
chunks
# Out:
# ['Generative artificial intelligence (GenAI) is a',
#  'is a subfield of artificial intelligence (AI)',
#  '(AI) that uses generative models to generate',
#  'generate text, images, videos, audio, software',
#  'software code or other forms of data.',
#  'These models learn the underlying patterns and',
#  'and structures of their training data, and use',
#  'and use them to generate new data in response to',
#  'to input, which often takes the form of natural',
#  'natural language prompts.',
#  'The prevalence of generative AI tools has',
#  'tools has increased significantly since the AI',
#  'the AI boom in the 2020s. This boom was made',
#  'was made possible by improvements in deep neural',
#  'neural networks, particularly large language',
#  'language models (LLMs), which are based on the',
#  'on the transformer architecture.']

# %% [markdown]
# ### Document Text Loader

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader(
    "../data/DBE.txt",
    encoding="utf-8"
)
texts = loader.load()

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# %%
text_chunks = splitter.split_documents(texts)
text_chunks
# Out:
# [Document(metadata={'source': '../data/DBE.txt'}, page_content='*Dream      *Build  *Empire\n=========================================================================\n\nFor DreamBuildEmpire, keep a fixed weekly content system so followers know what to expect.\n\n🚀 DreamBuildEmpire Weekly Content Calendar\nDay\tSeries\tGoal\nMonday\t🔮 Future Tech Monday\tEmerging technologies\nTuesday\t⚙️ AI Systems Tuesday\tTeach AI concepts\nWednesday\t🧠 Builder Mindset Wednesday\tThinking & discipline\nThursday\t🎙️ Founder Series Thursday\tFounder stories\nFriday\t📈 Startup Breakdown Friday\tBusiness models\nSaturday\t🚀 Future Builder Saturday\tSkills & careers\nSunday\t📚 Builder Resources Sunday\tTools & resources\nMonday\n🔮 Future Tech Monday\n\nExamples:\n\nAI Agents vs AI Assistants\nHumanoid Robots\nBrain-Computer Interfaces\nAI Operating Systems\nFuture of Software Development\n\nGoal:\n\nMake people curious about the future.\n\nTuesday\n⚙️ AI Systems Tuesday\n\nExamples:\n\nHow AI Agents Work\nRAG Explained\nMCP Explained\nVector Databases\nAI Memory Systems\nAgentic Workflows\n\nGoal:\n\nTeach technology simply.'),
#  Document(metadata={'source': '../data/DBE.txt'}, page_content="Tuesday\n⚙️ AI Systems Tuesday\n\nExamples:\n\nHow AI Agents Work\nRAG Explained\nMCP Explained\nVector Databases\nAI Memory Systems\nAgentic Workflows\n\nGoal:\n\nTeach technology simply.\n\nWednesday\n🧠 Builder Mindset Wednesday\n\nExamples:\n\nWhy Consistency Beats Talent\nNobody Cares About Your First Product\nBuild Before You're Ready\nThe Compound Effect\nLearn → Build → Share\n\nGoal:\n\nBuild connection with audience.\n\nThursday\n🎙️ Founder Series Thursday\n\nExamples:\n\nSridhar Vembu\nNikhil Kamath\nBhavish Aggarwal\nNarayana Murthy\nDeepinder Goyal\nJensen Huang\n\nStructure:\n\nStory\n→ Struggle\n→ Turning Point\n→ Lesson\n\nGoal:\n\nInspire future builders.\n\nFriday\n📈 Startup Breakdown Friday\n\nExamples:\n\nZerodha\nZoho\nPorter\nNinjacart\nSmallest.ai\nPerplexity\n\nStructure:\n\nProblem\n→ Solution\n→ Business Model\n→ Moat\n→ Lesson\n\nGoal:\n\nTeach business thinking.\n\nSaturday\n🚀 Future Builder Saturday\n\nExamples:"),
#  Document(metadata={'source': '../data/DBE.txt'}, page_content='Zerodha\nZoho\nPorter\nNinjacart\nSmallest.ai\nPerplexity\n\nStructure:\n\nProblem\n→ Solution\n→ Business Model\n→ Moat\n→ Lesson\n\nGoal:\n\nTeach business thinking.\n\nSaturday\n🚀 Future Builder Saturday\n\nExamples:\n\nAI Skills For 2030\nAgent Engineer Roadmap\nBuilder Skill Stack\nFuture Careers\nLearn FastAPI in 2026\nHow To Become An AI Builder\n\nGoal:\n\nHelp people become builders.\n\nSunday\n📚 Builder Resources Sunday\n\nExamples:\n\n10 Free AI Tools\n10 Founder Books\nBest AI Newsletters\nAI Learning Roadmap\nWebsites Every Builder Uses\nTop GitHub Repositories\n\nGoal:\n\nHigh saves and shares.\n\nContent Formula\n\nEvery Carousel:\n\nSlide 1\n\nStrong Hook\n\nSlide 2-6\n\nValue\n\nSlide 7\n\nKey Insight\n\nSlide 8\n\nTakeaway + Follow CTA\n\nLong-Term Vision\n\nYear 1:\n\nLearn storytelling\nLearn hooks\nBuild consistency\n\nYear 2:\n\nGrow audience\nLaunch newsletter\nBuild community\n\nYear 3+:\n\nDreamBuildEmpire becomes:\nTech Media Brand\nAI Education Brand\nDistribution channel for your future Agentic AI SaaS products'),
#  Document(metadata={'source': '../data/DBE.txt'}, page_content="Year 2:\n\nGrow audience\nLaunch newsletter\nBuild community\n\nYear 3+:\n\nDreamBuildEmpire becomes:\nTech Media Brand\nAI Education Brand\nDistribution channel for your future Agentic AI SaaS products\n\nThis is the content system I'd keep for the next 6–12 months without changing it. Consistency of theme matters more than constantly changing topics.\n\n\n\n\n\n\ndreambuildempire\n\n\nWrite a caption...\n\nAdd location\nAdd collaborators\nAlt text describes your photos for people with visual impairments. Alt text will be automatically created for your photos or you can choose to write your own.\nWrite alt text...\nHide like and view counts on this post\n\nOnly you will see the total number of likes and views on this post. You can change this later by going to the ··· menu at the top of the post. To hide like counts on other people's posts, go to your account settings. Learn more\nTurn off commenting\n\nYou can change this later by going to the ··· menu at the top of your post.\nAutomatically share to Threads"),
#  Document(metadata={'source': '../data/DBE.txt'}, page_content="You can change this later by going to the ··· menu at the top of your post.\nAutomatically share to Threads\n\nAlways share your posts to Threads. You can change your audience on Threads settings Learn more\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nI'll remember that DreamBuildEmpire is your long-term tech media brand and that you use:\n\n🔮 Future Tech Monday\n⚙️ AI Systems Tuesday\n🧠 Builder Mindset Wednesday\n🎙️ Founder Series Thursday\n📈 Startup Breakdown Friday\n🚀 Future Builder Saturday\n📚 Builder Resources Sunday\n\nAnd your preferred visual style:\n\n⚫ Black background\n🟨 Gold accents\n🟪 Purple highlights\n✍️ Handwritten notebook/carousel design\nFocus on AI, startups, founders, innovation, and future builders\n\nGoing forward, I can use this framework when helping you plan topics, carousels, captions, growth experiments, and content strategy for DreamBuildEmpire.")]

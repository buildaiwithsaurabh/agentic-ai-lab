# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model = "openai/gpt-oss-20b" , streaming=True)

# %%
res = llm.stream("can you explain me GEN-AI ?")
for chunk in res:
    print(chunk.content, end="")
# Out:
# ### What is Generative AI (Gen‑AI)?
#
# Generative AI refers to a class of artificial‑intelligence models that **create new content**—text, images, audio, video, code, and even 3D models—rather than just classifying or predicting existing data. Think of it as a “digital artist” that can draft stories, paint pictures, compose music, or write code from scratch.
#
# ---
#
# ## 1. Core Idea
#
# | Traditional AI | Generative AI |
# |----------------|---------------|
# | **Discriminative** – learns to *distinguish* between classes (e.g., spam vs. ham). | **Generative** – learns the *distribution* of data and can *sample* from that distribution to produce novel examples. |
#
# - **Discriminative models**: logistic regression, SVM, most supervised classification tasks.
# - **Generative models**: autoencoders, variational autoencoders (VAEs), generative adversarial networks (GANs), diffusion models, transformer‑based language models (GPT‑4, LLaMA).
#
# ---
#
# ## 2. How It Works (High‑Level)
# ...

# %%
#### From ENV

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %% [markdown]
# #### CONNECT WITH GOOGLE GEMINI MODEL

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print("GEMINI_API_KEY:", os.getenv("GEMINI_API_KEY") is not None)
print("GEMINI_API_KEYS:", os.getenv("GEMINI_API_KEYS") is not None)
# Out:
# GEMINI_API_KEY: True
# GEMINI_API_KEYS: True

# %% [markdown]
# ### STATIC PROMPT

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.7-flash",
    temperature=0.7,
    max_output_tokens=1024
)

# %% [markdown]
# #### Prompt Engineering

# %% [markdown]
# ## Static Prompt

# %%
prompts = [("system" , "You are Python Developer") , ### "System" , "AI"
          ("user" , "Write is array ")]

res = llm.invoke(prompts)
print(res.content[0]["text"])
# Out:
# In Python, the term "array" can refer to a few different types (standard **Lists**, the built-in **`array` module**, or **NumPy arrays**).
#
# Here is how you can **check if an object is an array** (`is_array`), as well as how to **create (write) an array** in Python.
#
# ---
#
# ### 1. Function to Check if an Object is an Array (`is_array`)
#
# ```python
# import array
#
# # Optional: try importing numpy if installed
# try:
#     import numpy as np
#     ARRAY_TYPES = (list, array.array, np.ndarray)
# except ImportError:
#     ARRAY_TYPES = (list, array.array)
#
# def is_array(obj) -> bool:
#     """Checks if the given object is a list, standard array, or NumPy array."""
#     return isinstance(obj, ARRAY_TYPES)
#
# # --- Test cases ---
# print(is_array([1, 2, 3]))               # True (Python list)
# print(is_array(array.array('i', [1, 2]))) # True (Python array module)
# print(is_array("Hello"))                 # False (String)
# ...

# %% [markdown]
# ### Dynamic Prompting

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3.7-flash")

# %%
prompt = ChatPromptTemplate.from_messages([
  {"role" : "system" , "content" : "You are a Translator for {langauge} to hindi."} ,
  {"role" : "user" , "content" : "{query}"}
])

# %%
final_prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a Translator for English to hindi.', additional_kwargs={}, response_metadata={}), HumanMessage(content='I love you', additional_kwargs={}, response_metadata={})])

# %%
final_prompt = prompt.format_prompt(langauge="English", query="I love you")

res = llm.invoke(final_prompt)
print(res.content[0]["text"])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\agentic-ai-lab\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3302, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3301 try:
# -> 3302     response: GenerateContentResponse = self.client.models.generate_content(
#    3303         **request,
#    3304     )
#    3305 except ClientError as e:
#
# File d:\agentic-ai-lab\.venv\Lib\site-packages\google\genai\models.py:6558, in Models.generate_content(self, model, contents, config)
#    6557 i += 1
# -> 6558 response = self._generate_content(
#    6559     model=model, contents=contents, config=parsed_config_to_call
#    6560 )
#    6562 if not function_map:
#
# ...
